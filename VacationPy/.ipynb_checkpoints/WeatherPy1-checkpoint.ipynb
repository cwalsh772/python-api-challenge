# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
weather_api_key = "d0613004fa405a4f72a41754bc37747c"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 581

# %%
url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID="
target_url = url + weather_api_key
target_url
# Out:
# 'http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=d0613004fa405a4f72a41754bc37747c'

# %%
weather_response = requests.get(target_url)
weather_json = weather_response.json()
#print(json.dumps(weather_json, indent=4, sort_keys=True))

# %%
#print(weather_json['city']['name'])
print(weather_json['city']['name'])
# Out:
# Moscow

# %%
# set up lists to hold reponse info
cityname = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
count = 0

#  response = requests.get(query_url + city).json()
    
# Loop through the list of cities and perform a request for data on each

for city in cities:
    weather_response = requests.get(target_url + "&q=" + city + "&units=Imperial")
    weather_json = weather_response.json()
    try:
        cityname.append(weather_json['city']['name'])
        cloudiness.append(weather_json['list'][0]['clouds']['all'])
        country.append(weather_json['city']['country'])
        date.append(weather_json['list'][0]['dt'])
        humidity.append(weather_json['list'][0]['main']['humidity'])
        lat.append(weather_json['city']['coord']['lat'])
        lng.append(weather_json['city']['coord']['lon'])
        max_temp.append(weather_json['list'][0]['main']['temp_max'])
        wind_speed.append(weather_json['list'][0]['wind']['speed'])
        count = count + 1
        print(f"Processing record {count} of Set 1 | {city}")
    except:
        print("Record not found") 
        pass
# Out:
# Record not found
# Record not found
# Processing record 1 of Set 1 | nikolskoye
# Processing record 2 of Set 1 | quebec
# Processing record 3 of Set 1 | chandler
# Processing record 4 of Set 1 | busselton
# Processing record 5 of Set 1 | fairbanks
# Processing record 6 of Set 1 | atuona
# Processing record 7 of Set 1 | san cristobal
# Processing record 8 of Set 1 | rikitea
# Processing record 9 of Set 1 | port macquarie
# Processing record 10 of Set 1 | mar del plata
# Processing record 11 of Set 1 | punta arenas
# Processing record 12 of Set 1 | yellowknife
# Record not found
# Processing record 13 of Set 1 | hasaki
# Processing record 14 of Set 1 | narsaq
# Processing record 15 of Set 1 | norman wells
# Processing record 16 of Set 1 | butaritari
# Record not found
# Processing record 17 of Set 1 | bluff
# Processing record 18 of Set 1 | hilo
# Processing record 19 of Set 1 | torbay
# Processing record 20 of Set 1 | gashua
# Processing record 21 of Set 1 | hermanus
# Processing record 22 of Set 1 | tuktoyaktuk
# Processing record 23 of Set 1 | saskylakh
# Processing record 24 of Set 1 | cidreira
# Processing record 25 of Set 1 | noumea
# Processing record 26 of Set 1 | port-gentil
# Processing record 27 of Set 1 | saldanha
# Record not found
# Processing record 28 of Set 1 | bilma
# Processing record 29 of Set 1 | provideniya
# Record not found
# Processing record 30 of Set 1 | mombetsu
# Processing record 31 of Set 1 | villazon
# Processing record 32 of Set 1 | cubuk
# Processing record 33 of Set 1 | presidente epitacio
# Processing record 34 of Set 1 | nayoro
# Record not found
# Processing record 35 of Set 1 | laguna
# Processing record 36 of Set 1 | kapaa
# Processing record 37 of Set 1 | ushuaia
# Processing record 38 of Set 1 | pisco
# Processing record 39 of Set 1 | albany
# Processing record 40 of Set 1 | georgetown
# Processing record 41 of Set 1 | qaanaaq
# Processing record 42 of Set 1 | hobart
# Processing record 43 of Set 1 | lebu
# Processing record 44 of Set 1 | cape town
# Processing record 45 of Set 1 | kahului
# Processing record 46 of Set 1 | vaini
# Processing record 47 of Set 1 | kailua
# Processing record 48 of Set 1 | mataura
# Processing record 49 of Set 1 | beyneu
# Processing record 50 of Set 1 | saint-pierre
# Record not found
# Processing record 51 of Set 1 | harper
# Record not found
# Processing record 52 of Set 1 | barrow
# Processing record 53 of Set 1 | namatanai
# Processing record 54 of Set 1 | zhangye
# Processing record 55 of Set 1 | clarence town
# Processing record 56 of Set 1 | halifax
# Processing record 57 of Set 1 | arraial do cabo
# Processing record 58 of Set 1 | bambanglipuro
# Processing record 59 of Set 1 | thompson
# Processing record 60 of Set 1 | palmer
# Record not found
# Processing record 61 of Set 1 | thinadhoo
# Record not found
# Record not found
# Processing record 62 of Set 1 | litovko
# Processing record 63 of Set 1 | stornoway
# Processing record 64 of Set 1 | port elizabeth
# Processing record 65 of Set 1 | victoria
# Processing record 66 of Set 1 | kaitangata
# Processing record 67 of Set 1 | faanui
# Processing record 68 of Set 1 | half moon bay
# Processing record 69 of Set 1 | vao
# Processing record 70 of Set 1 | esperance
# Record not found
# Processing record 71 of Set 1 | verkhoyansk
# Processing record 72 of Set 1 | sitka
# Processing record 73 of Set 1 | bredasdorp
# Processing record 74 of Set 1 | saint-joseph
# Processing record 75 of Set 1 | vanimo
# Processing record 76 of Set 1 | kibala
# Processing record 77 of Set 1 | kodiak
# Processing record 78 of Set 1 | omboue
# Processing record 79 of Set 1 | katsuura
# Processing record 80 of Set 1 | severo-kurilsk
# Processing record 81 of Set 1 | freeport
# Processing record 82 of Set 1 | waingapu
# Processing record 83 of Set 1 | bethel
# Processing record 84 of Set 1 | rock sound
# Processing record 85 of Set 1 | izhma
# Processing record 86 of Set 1 | klamath falls
# Processing record 87 of Set 1 | grand gaube
# Processing record 88 of Set 1 | newcastleton
# Processing record 89 of Set 1 | namibe
# Processing record 90 of Set 1 | yining
# Processing record 91 of Set 1 | new norfolk
# Processing record 92 of Set 1 | bandar-e lengeh
# Processing record 93 of Set 1 | khategaon
# Processing record 94 of Set 1 | barabai
# Processing record 95 of Set 1 | havre-saint-pierre
# Record not found
# Processing record 96 of Set 1 | sumbe
# Processing record 97 of Set 1 | castro
# Processing record 98 of Set 1 | muisne
# Processing record 99 of Set 1 | hirado
# Processing record 100 of Set 1 | hithadhoo
# Processing record 101 of Set 1 | lahat
# Processing record 102 of Set 1 | antofagasta
# Processing record 103 of Set 1 | abha
# Processing record 104 of Set 1 | whitehorse
# Processing record 105 of Set 1 | ambilobe
# Processing record 106 of Set 1 | northam
# Record not found
# Processing record 107 of Set 1 | loanda
# Processing record 108 of Set 1 | ponta do sol
# Processing record 109 of Set 1 | port alfred
# Processing record 110 of Set 1 | inirida
# Processing record 111 of Set 1 | muros
# Processing record 112 of Set 1 | ribeira grande
# Processing record 113 of Set 1 | hami
# Processing record 114 of Set 1 | mahebourg
# Processing record 115 of Set 1 | shuyskoye
# Processing record 116 of Set 1 | yuzhno-kurilsk
# Processing record 117 of Set 1 | sulechow
# Processing record 118 of Set 1 | maniitsoq
# Processing record 119 of Set 1 | nuuk
# Processing record 120 of Set 1 | sfantu gheorghe
# Processing record 121 of Set 1 | mindelo
# Processing record 122 of Set 1 | port pirie
# Record not found
# Processing record 123 of Set 1 | kamenka
# Processing record 124 of Set 1 | srednekolymsk
# Processing record 125 of Set 1 | tuatapere
# Processing record 126 of Set 1 | kondoa
# Processing record 127 of Set 1 | upernavik
# Processing record 128 of Set 1 | carnarvon
# Processing record 129 of Set 1 | susanino
# Processing record 130 of Set 1 | jamestown
# Processing record 131 of Set 1 | te anau
# Processing record 132 of Set 1 | lorengau
# Processing record 133 of Set 1 | koumac
# Processing record 134 of Set 1 | sao francisco de assis
# Record not found
# Processing record 135 of Set 1 | ushtobe
# Processing record 136 of Set 1 | banda aceh
# Processing record 137 of Set 1 | bagacay
# Record not found
# Processing record 138 of Set 1 | lundazi
# Processing record 139 of Set 1 | leningradskiy
# Processing record 140 of Set 1 | senador jose porfirio
# Processing record 141 of Set 1 | chuy
# Processing record 142 of Set 1 | san andres
# Processing record 143 of Set 1 | guerrero negro
# Processing record 144 of Set 1 | kankan
# Processing record 145 of Set 1 | margate
# Processing record 146 of Set 1 | kenai
# Processing record 147 of Set 1 | kaduna
# Processing record 148 of Set 1 | fort nelson
# Processing record 149 of Set 1 | sao filipe
# Processing record 150 of Set 1 | hovd
# Processing record 151 of Set 1 | saint anthony
# Processing record 152 of Set 1 | gazojak
# Processing record 153 of Set 1 | tubmanburg
# Processing record 154 of Set 1 | shagamu
# Processing record 155 of Set 1 | cherskiy
# Processing record 156 of Set 1 | vila franca do campo
# Processing record 157 of Set 1 | pacific grove
# Processing record 158 of Set 1 | ocos
# Processing record 159 of Set 1 | clyde river
# Processing record 160 of Set 1 | adrar
# Record not found
# Processing record 161 of Set 1 | dikson
# Processing record 162 of Set 1 | brae
# Processing record 163 of Set 1 | capreol
# Processing record 164 of Set 1 | kondinskoye
# Processing record 165 of Set 1 | tiznit
# Processing record 166 of Set 1 | ust-maya
# Processing record 167 of Set 1 | husavik
# Processing record 168 of Set 1 | anloga
# Processing record 169 of Set 1 | matagami
# Processing record 170 of Set 1 | tongren
# Processing record 171 of Set 1 | lexington
# Processing record 172 of Set 1 | westport
# Processing record 173 of Set 1 | nome
# Processing record 174 of Set 1 | nanga eboko
# Processing record 175 of Set 1 | east london
# Processing record 176 of Set 1 | chinsali
# Processing record 177 of Set 1 | lima
# Processing record 178 of Set 1 | kiunga
# Processing record 179 of Set 1 | tocopilla
# Processing record 180 of Set 1 | taunggyi
# Processing record 181 of Set 1 | batemans bay
# Processing record 182 of Set 1 | bridlington
# Processing record 183 of Set 1 | saint-philippe
# Record not found
# Processing record 184 of Set 1 | tilichiki
# Processing record 185 of Set 1 | paysandu
# Processing record 186 of Set 1 | mozhaysk
# Processing record 187 of Set 1 | olafsvik
# Processing record 188 of Set 1 | malatya
# Processing record 189 of Set 1 | ahuimanu
# Processing record 190 of Set 1 | sobolevo
# Processing record 191 of Set 1 | narrabri
# Processing record 192 of Set 1 | amapa
# Processing record 193 of Set 1 | puerto ayora
# Processing record 194 of Set 1 | limoeiro do ajuru
# Processing record 195 of Set 1 | longyearbyen
# Processing record 196 of Set 1 | boralday
# Processing record 197 of Set 1 | bengkulu
# Processing record 198 of Set 1 | lata
# Processing record 199 of Set 1 | galich
# Processing record 200 of Set 1 | carbonia
# Processing record 201 of Set 1 | dunedin
# Record not found
# Processing record 202 of Set 1 | letlhakane
# Processing record 203 of Set 1 | upington
# Processing record 204 of Set 1 | dickinson
# Processing record 205 of Set 1 | souillac
# Record not found
# Processing record 206 of Set 1 | kieta
# Processing record 207 of Set 1 | khatanga
# Processing record 208 of Set 1 | paengaroa
# Processing record 209 of Set 1 | ust-kan
# Processing record 210 of Set 1 | rocha
# Processing record 211 of Set 1 | bathsheba
# Processing record 212 of Set 1 | machala
# Processing record 213 of Set 1 | takhtamygda
# Record not found
# Processing record 214 of Set 1 | kilindoni
# Processing record 215 of Set 1 | palana
# Processing record 216 of Set 1 | hofn
# Record not found
# Processing record 217 of Set 1 | sabang
# Processing record 218 of Set 1 | chalon-sur-saone
# Processing record 219 of Set 1 | izmir
# Processing record 220 of Set 1 | sambava
# Processing record 221 of Set 1 | avarua
# Processing record 222 of Set 1 | vardo
# Processing record 223 of Set 1 | havoysund
# Processing record 224 of Set 1 | chokurdakh
# Processing record 225 of Set 1 | cabo san lucas
# Processing record 226 of Set 1 | kampot
# Processing record 227 of Set 1 | revda
# Processing record 228 of Set 1 | ostrovnoy
# Processing record 229 of Set 1 | bodden town
# Processing record 230 of Set 1 | keokuk
# Processing record 231 of Set 1 | corrente
# Processing record 232 of Set 1 | karratha
# Processing record 233 of Set 1 | algiers
# Processing record 234 of Set 1 | mehamn
# Processing record 235 of Set 1 | sandnessjoen
# Processing record 236 of Set 1 | tiksi
# Processing record 237 of Set 1 | shubarshi
# Processing record 238 of Set 1 | jalu
# Processing record 239 of Set 1 | casablanca
# Processing record 240 of Set 1 | ko samui
# Processing record 241 of Set 1 | korla
# Processing record 242 of Set 1 | poso
# Processing record 243 of Set 1 | calbuco
# Processing record 244 of Set 1 | klaksvik
# Processing record 245 of Set 1 | belaya gora
# Processing record 246 of Set 1 | dauphin
# Processing record 247 of Set 1 | constantine
# Processing record 248 of Set 1 | vilhena
# Processing record 249 of Set 1 | formosa
# Processing record 250 of Set 1 | paoua
# Processing record 251 of Set 1 | vestmannaeyjar
# Processing record 252 of Set 1 | caravelas
# Processing record 253 of Set 1 | tura
# Processing record 254 of Set 1 | yulara
# Processing record 255 of Set 1 | luangwa
# Processing record 256 of Set 1 | okha
# Processing record 257 of Set 1 | port blair
# Processing record 258 of Set 1 | zhigansk
# Processing record 259 of Set 1 | dzhebariki-khaya
# Processing record 260 of Set 1 | petropavlovsk-kamchatskiy
# Processing record 261 of Set 1 | inhambane
# Processing record 262 of Set 1 | valparaiso
# Processing record 263 of Set 1 | puerto escondido
# Processing record 264 of Set 1 | porto da folha
# Processing record 265 of Set 1 | kihei
# Processing record 266 of Set 1 | svetlaya
# Processing record 267 of Set 1 | codrington
# Processing record 268 of Set 1 | lompoc
# Processing record 269 of Set 1 | kangaatsiaq
# Processing record 270 of Set 1 | fortuna
# Processing record 271 of Set 1 | kenora
# Record not found
# Processing record 272 of Set 1 | manicore
# Processing record 273 of Set 1 | herat
# Processing record 274 of Set 1 | acapulco
# Processing record 275 of Set 1 | port hedland
# Processing record 276 of Set 1 | lazaro cardenas
# Processing record 277 of Set 1 | mount isa
# Processing record 278 of Set 1 | bara
# Processing record 279 of Set 1 | tasiilaq
# Processing record 280 of Set 1 | limbe
# Processing record 281 of Set 1 | sunnyside
# Processing record 282 of Set 1 | touros
# Processing record 283 of Set 1 | boddam
# Processing record 284 of Set 1 | uren
# Processing record 285 of Set 1 | bambous virieux
# Processing record 286 of Set 1 | akdepe
# Processing record 287 of Set 1 | saint george
# Processing record 288 of Set 1 | elizabeth city
# Record not found
# Processing record 289 of Set 1 | labuhan
# Processing record 290 of Set 1 | atar
# Processing record 291 of Set 1 | moyale
# Processing record 292 of Set 1 | taltal
# Processing record 293 of Set 1 | ningyang
# Processing record 294 of Set 1 | berlevag
# Processing record 295 of Set 1 | fort wellington
# Processing record 296 of Set 1 | bud
# Processing record 297 of Set 1 | quatre cocos
# Processing record 298 of Set 1 | mayo
# Processing record 299 of Set 1 | virginia beach
# Processing record 300 of Set 1 | oyek
# Processing record 301 of Set 1 | zvenigovo
# Processing record 302 of Set 1 | vanavara
# Processing record 303 of Set 1 | coihaique
# Processing record 304 of Set 1 | isangel
# Processing record 305 of Set 1 | anamur
# Processing record 306 of Set 1 | hamilton
# Processing record 307 of Set 1 | aklavik
# Record not found
# Processing record 308 of Set 1 | kavieng
# Processing record 309 of Set 1 | cedar city
# Processing record 310 of Set 1 | romny
# Processing record 311 of Set 1 | usinsk
# Processing record 312 of Set 1 | tessalit
# Processing record 313 of Set 1 | kwinana
# Processing record 314 of Set 1 | hirara
# Processing record 315 of Set 1 | itarema
# Processing record 316 of Set 1 | ugoofaaru
# Processing record 317 of Set 1 | rawson
# Processing record 318 of Set 1 | astorga
# Record not found
# Processing record 319 of Set 1 | evensk
# Processing record 320 of Set 1 | gornopravdinsk
# Processing record 321 of Set 1 | taoudenni
# Processing record 322 of Set 1 | longford
# Processing record 323 of Set 1 | ajdabiya
# Processing record 324 of Set 1 | qaqortoq
# Processing record 325 of Set 1 | pucallpa
# Processing record 326 of Set 1 | oistins
# Processing record 327 of Set 1 | alofi
# Processing record 328 of Set 1 | shangrao
# Processing record 329 of Set 1 | malacky
# Processing record 330 of Set 1 | san jose
# Processing record 331 of Set 1 | inverell
# Processing record 332 of Set 1 | nsanje
# Processing record 333 of Set 1 | pevek
# Processing record 334 of Set 1 | khor
# Processing record 335 of Set 1 | san quintin
# Processing record 336 of Set 1 | sao joao da barra
# Processing record 337 of Set 1 | yar-sale
# Processing record 338 of Set 1 | karpogory
# Processing record 339 of Set 1 | jiblah
# Processing record 340 of Set 1 | biggar
# Record not found
# Processing record 341 of Set 1 | smithers
# Processing record 342 of Set 1 | kanturk
# Processing record 343 of Set 1 | millinocket
# Processing record 344 of Set 1 | mandalgovi
# Processing record 345 of Set 1 | llandrindod wells
# Processing record 346 of Set 1 | lagoa
# Processing record 347 of Set 1 | apollonia
# Processing record 348 of Set 1 | camacha
# Record not found
# Processing record 349 of Set 1 | talnakh
# Processing record 350 of Set 1 | nagato
# Processing record 351 of Set 1 | carutapera
# Record not found
# Processing record 352 of Set 1 | san patricio
# Processing record 353 of Set 1 | tafresh
# Processing record 354 of Set 1 | nishihara
# Processing record 355 of Set 1 | kushmurun
# Processing record 356 of Set 1 | rio grande
# Processing record 357 of Set 1 | zhanaozen
# Processing record 358 of Set 1 | la rioja
# Processing record 359 of Set 1 | yeppoon
# Processing record 360 of Set 1 | arlit
# Processing record 361 of Set 1 | cam ranh
# Record not found
# Record not found
# Processing record 362 of Set 1 | schrobenhausen
# Processing record 363 of Set 1 | kampene
# Processing record 364 of Set 1 | fria
# Processing record 365 of Set 1 | kaeo
# Processing record 366 of Set 1 | tieling
# Processing record 367 of Set 1 | padang
# Processing record 368 of Set 1 | geraldton
# Processing record 369 of Set 1 | kosino
# Processing record 370 of Set 1 | yalta
# Processing record 371 of Set 1 | peno
# Processing record 372 of Set 1 | la ronge
# Processing record 373 of Set 1 | havelock
# Processing record 374 of Set 1 | yinchuan
# Processing record 375 of Set 1 | neuquen
# Processing record 376 of Set 1 | niquero
# Processing record 377 of Set 1 | kozulka
# Processing record 378 of Set 1 | burnie
# Processing record 379 of Set 1 | itoman
# Processing record 380 of Set 1 | ginda
# Processing record 381 of Set 1 | kuopio
# Record not found
# Processing record 382 of Set 1 | bronnoysund
# Processing record 383 of Set 1 | minas
# Processing record 384 of Set 1 | lavrentiya
# Processing record 385 of Set 1 | port hardy
# Processing record 386 of Set 1 | porangatu
# Processing record 387 of Set 1 | colares
# Record not found
# Processing record 388 of Set 1 | fereydun kenar
# Processing record 389 of Set 1 | davila
# Processing record 390 of Set 1 | hualmay
# Processing record 391 of Set 1 | pervomayskoye
# Processing record 392 of Set 1 | sanchez
# Processing record 393 of Set 1 | gasa
# Processing record 394 of Set 1 | rondonopolis
# Processing record 395 of Set 1 | quesnel
# Processing record 396 of Set 1 | vostok
# Record not found
# Processing record 397 of Set 1 | batagay-alyta
# Processing record 398 of Set 1 | toppenish
# Processing record 399 of Set 1 | olinda
# Processing record 400 of Set 1 | aksu
# Processing record 401 of Set 1 | ust-kut
# Processing record 402 of Set 1 | port augusta
# Processing record 403 of Set 1 | high level
# Processing record 404 of Set 1 | iqaluit
# Processing record 405 of Set 1 | channel-port aux basques
# Processing record 406 of Set 1 | raglan
# Processing record 407 of Set 1 | itabira
# Processing record 408 of Set 1 | gravelbourg
# Processing record 409 of Set 1 | mersing
# Processing record 410 of Set 1 | haimen
# Processing record 411 of Set 1 | kruisfontein
# Processing record 412 of Set 1 | colan
# Processing record 413 of Set 1 | krasnoshchekovo
# Processing record 414 of Set 1 | tautira
# Processing record 415 of Set 1 | fatehpur
# Record not found
# Processing record 416 of Set 1 | porto walter
# Record not found
# Processing record 417 of Set 1 | plettenberg bay
# Processing record 418 of Set 1 | tezu
# Processing record 419 of Set 1 | coquimbo
# Processing record 420 of Set 1 | shache
# Processing record 421 of Set 1 | mount gambier
# Processing record 422 of Set 1 | pochutla
# Processing record 423 of Set 1 | casper
# Processing record 424 of Set 1 | atbasar
# Processing record 425 of Set 1 | madimba
# Processing record 426 of Set 1 | necochea
# Processing record 427 of Set 1 | maihar
# Record not found
# Processing record 428 of Set 1 | sembakung
# Processing record 429 of Set 1 | punta alta
# Processing record 430 of Set 1 | tatawin
# Processing record 431 of Set 1 | yaan
# Processing record 432 of Set 1 | cafelandia
# Processing record 433 of Set 1 | port lincoln
# Processing record 434 of Set 1 | alekseyevskaya
# Processing record 435 of Set 1 | marsh harbour
# Processing record 436 of Set 1 | cascais
# Processing record 437 of Set 1 | bereda
# Processing record 438 of Set 1 | yatou
# Processing record 439 of Set 1 | bonfim
# Processing record 440 of Set 1 | eirunepe
# Processing record 441 of Set 1 | flin flon
# Record not found
# Processing record 442 of Set 1 | neiafu
# Processing record 443 of Set 1 | cozumel
# Processing record 444 of Set 1 | naze
# Record not found
# Processing record 445 of Set 1 | chambersburg
# Processing record 446 of Set 1 | cockburn town
# Processing record 447 of Set 1 | moose factory
# Processing record 448 of Set 1 | aljezur
# Processing record 449 of Set 1 | ciudad bolivar
# Processing record 450 of Set 1 | liverpool
# Processing record 451 of Set 1 | constitucion
# Record not found
# Record not found
# Processing record 452 of Set 1 | baruun-urt
# Processing record 453 of Set 1 | ambulu
# Processing record 454 of Set 1 | airai
# Processing record 455 of Set 1 | kununurra
# Processing record 456 of Set 1 | muli
# Processing record 457 of Set 1 | filadelfia
# Processing record 458 of Set 1 | la asuncion
# Processing record 459 of Set 1 | aswan
# Processing record 460 of Set 1 | maningrida
# Processing record 461 of Set 1 | domoni
# Processing record 462 of Set 1 | camocim
# Processing record 463 of Set 1 | tonkino
# Processing record 464 of Set 1 | uvalde
# Processing record 465 of Set 1 | totton
# Processing record 466 of Set 1 | kudahuvadhoo
# Processing record 467 of Set 1 | san jeronimo
# Record not found
# Record not found
# Processing record 468 of Set 1 | lasa
# Processing record 469 of Set 1 | mkushi
# Processing record 470 of Set 1 | aranos
# Record not found
# Record not found
# Processing record 471 of Set 1 | gulu
# Record not found
# Processing record 472 of Set 1 | quelimane
# Processing record 473 of Set 1 | ankang
# Processing record 474 of Set 1 | verkhniy rohachyk
# Processing record 475 of Set 1 | eureka
# Processing record 476 of Set 1 | konstantinovka
# Processing record 477 of Set 1 | iwanai
# Processing record 478 of Set 1 | beatrice
# Processing record 479 of Set 1 | weligama
# Processing record 480 of Set 1 | coahuayana
# Processing record 481 of Set 1 | providencia
# Processing record 482 of Set 1 | swan hill
# Processing record 483 of Set 1 | wenzhou
# Processing record 484 of Set 1 | cerrito
# Processing record 485 of Set 1 | portland
# Processing record 486 of Set 1 | udarnyy
# Processing record 487 of Set 1 | shudayag
# Processing record 488 of Set 1 | salon-de-provence
# Processing record 489 of Set 1 | myitkyina
# Processing record 490 of Set 1 | leh
# Processing record 491 of Set 1 | xinpu
# Processing record 492 of Set 1 | ordu
# Processing record 493 of Set 1 | salalah
# Processing record 494 of Set 1 | pemangkat
# Processing record 495 of Set 1 | sananduva
# Processing record 496 of Set 1 | aitape
# Processing record 497 of Set 1 | ouango
# Processing record 498 of Set 1 | niimi
# Processing record 499 of Set 1 | ardakan
# Processing record 500 of Set 1 | concordia
# Processing record 501 of Set 1 | axim
# Processing record 502 of Set 1 | turukhansk
# Processing record 503 of Set 1 | alice springs
# Processing record 504 of Set 1 | inuvik
# Processing record 505 of Set 1 | ngunguru
# Processing record 506 of Set 1 | caxito
# Processing record 507 of Set 1 | aksarka
# Processing record 508 of Set 1 | vanderhoof
# Processing record 509 of Set 1 | kismayo
# Processing record 510 of Set 1 | sao miguel do araguaia
# Processing record 511 of Set 1 | ulladulla
# Processing record 512 of Set 1 | yuryev-polskiy
# Processing record 513 of Set 1 | peniche
# Processing record 514 of Set 1 | nova borova
# Processing record 515 of Set 1 | waipawa
# Processing record 516 of Set 1 | kemijarvi
# Processing record 517 of Set 1 | bahar
# Processing record 518 of Set 1 | znamensk
# Processing record 519 of Set 1 | grimshaw
# Processing record 520 of Set 1 | apodi
# Processing record 521 of Set 1 | konza
# Processing record 522 of Set 1 | kysyl-syr
# Processing record 523 of Set 1 | tiassale
# Processing record 524 of Set 1 | charters towers
# Processing record 525 of Set 1 | hobyo
# Processing record 526 of Set 1 | tarko-sale
# Processing record 527 of Set 1 | camana
# Processing record 528 of Set 1 | bavly
# Processing record 529 of Set 1 | nanortalik
# Processing record 530 of Set 1 | ilulissat
# Record not found
# Processing record 531 of Set 1 | los llanos de aridane
# Processing record 532 of Set 1 | mantenopolis

# %%
# Convert array of JSONs into Pandas DataFrame

weather_dict = {"City": cityname,"Latitude": lat, "Longitude":lng,
                "Max Temp":max_temp,"Humidity":humidity,"Cloudiness":cloudiness,
                "Wind Speed":wind_speed,"Country":country, "Date":date}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#          City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0  Nikolskoye   59.7035    30.7861     66.47        86           2
# 1      Québec   46.8123   -71.2145     70.79        71           3
# 2    Chandler   33.3062  -111.8412     93.87         8           1
# 3   Busselton  -33.6500   115.3333     56.88        75          68
# 4   Fairbanks   64.8378  -147.7164     74.50        31          85
#
#    Wind Speed Country        Date
# 0        2.24      RU  1592535600
# 1        5.03      CA  1592535600
# 2       12.80      US  1592535600
# 3        4.56      AU  1592535600
# 4        4.03      US  1592535600

# %%
# Export the City_Data into a csv
weather_data.to_csv(r'output_data\my_weather_data.csv')
# Show Record Count
countforme = len(weather_data)
countforme
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-2ef77ac13249> in <module>
#       1 # Export the City_Data into a csv
# ----> 2 weather_data.to_csv(r'output_data\my_weather_data.csv')
#       3 # Show Record Count
#       4 countforme = len(weather_data)
#       5 countforme
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'output_data\\my_weather_data.csv'

# %%
#Display the City Data Frame
weather_data.head()

# %%
# Build scatter plot for latitude vs. temperature
# Incorporate the other graph properties
# Save the figure
# Show plot
scatlat = weather_data["Latitude"]
scattemp = weather_data["Max Temp"]

plt.scatter(scatlat,scattemp)
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('scatplotlatitudemaxtemp')
plt.show()

#This code is analyzing the max temperature of each city and latitude.


# Build the scatter plots for latitude vs. humidity
# Incorporate the other graph properties
# Save the figure
# Show plot

#scatlat = weather_data["Latitude"]
scathum = weather_data["Humidity"]

plt.scatter(scatlat,scathum)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('scatplotlatitudehumidity')
plt.show()
