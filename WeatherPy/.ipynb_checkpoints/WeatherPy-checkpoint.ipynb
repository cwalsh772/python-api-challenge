# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
weather_api_key = "d0613004fa405a4f72a41754bc37747c"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID="
target_url = url + weather_api_key
target_url
# Out:
# 'http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=d0613004fa405a4f72a41754bc37747c'

# %%
weather_response = requests.get(target_url)
weather_json = weather_response.json()
#print(json.dumps(weather_json, indent=4, sort_keys=True))

# %%
#print(weather_json['city']['name'])
print(weather_json['city']['name'])
# Out:
# Moscow

# %%
# set up lists to hold reponse info
cityname = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
count = 0

#  response = requests.get(query_url + city).json()
    
# Loop through the list of cities and perform a request for data on each

for city in cities:
    weather_response = requests.get(target_url + "&q=" + city + "&units=Imperial")
    weather_json = weather_response.json()
    try:
        cityname.append(weather_json['city']['name'])
        cloudiness.append(weather_json['list'][0]['clouds']['all'])
        country.append(weather_json['city']['country'])
        date.append(weather_json['list'][0]['dt'])
        humidity.append(weather_json['list'][0]['main']['humidity'])
        lat.append(weather_json['city']['coord']['lat'])
        lng.append(weather_json['city']['coord']['lon'])
        max_temp.append(weather_json['list'][0]['main']['temp_max'])
        wind_speed.append(weather_json['list'][0]['wind']['speed'])
        count = count + 1
        print(f"Processing record {count} of Set 1 | {city}")
    except:
        print("Record not found") 
        pass
# Out:
# Processing record 1 of Set 1 | forest grove
# Processing record 2 of Set 1 | arraial do cabo
# Record not found
# Processing record 3 of Set 1 | albany
# Processing record 4 of Set 1 | broome
# Processing record 5 of Set 1 | hilo
# Processing record 6 of Set 1 | chokurdakh
# Processing record 7 of Set 1 | bredy
# Processing record 8 of Set 1 | waipawa
# Processing record 9 of Set 1 | kruisfontein
# Processing record 10 of Set 1 | ushuaia
# Processing record 11 of Set 1 | punta arenas
# Processing record 12 of Set 1 | grakhovo
# Processing record 13 of Set 1 | klaksvik
# Record not found
# Processing record 14 of Set 1 | kapaa
# Processing record 15 of Set 1 | saint-philippe
# Processing record 16 of Set 1 | vardo
# Processing record 17 of Set 1 | laguna
# Processing record 18 of Set 1 | camacha
# Processing record 19 of Set 1 | avera
# Processing record 20 of Set 1 | bredasdorp
# Processing record 21 of Set 1 | bambous virieux
# Processing record 22 of Set 1 | birin
# Processing record 23 of Set 1 | tiksi
# Processing record 24 of Set 1 | san cristobal
# Processing record 25 of Set 1 | hobart
# Processing record 26 of Set 1 | mehamn
# Processing record 27 of Set 1 | buraydah
# Processing record 28 of Set 1 | oktyabrskoye
# Processing record 29 of Set 1 | norman wells
# Processing record 30 of Set 1 | busselton
# Processing record 31 of Set 1 | butaritari
# Record not found
# Processing record 32 of Set 1 | luau
# Processing record 33 of Set 1 | tafresh
# Processing record 34 of Set 1 | koroni
# Processing record 35 of Set 1 | lebu
# Processing record 36 of Set 1 | mundo nuevo
# Processing record 37 of Set 1 | new norfolk
# Processing record 38 of Set 1 | ballina
# Processing record 39 of Set 1 | trinidad
# Processing record 40 of Set 1 | sobolevo
# Processing record 41 of Set 1 | rikitea
# Processing record 42 of Set 1 | havre-saint-pierre
# Processing record 43 of Set 1 | aswan
# Processing record 44 of Set 1 | port hedland
# Processing record 45 of Set 1 | nizwa
# Processing record 46 of Set 1 | lesce
# Processing record 47 of Set 1 | kampot
# Processing record 48 of Set 1 | georgetown
# Processing record 49 of Set 1 | baoro
# Processing record 50 of Set 1 | auki
# Processing record 51 of Set 1 | kahului
# Processing record 52 of Set 1 | thompson
# Processing record 53 of Set 1 | jamestown
# Processing record 54 of Set 1 | yerbogachen
# Processing record 55 of Set 1 | denpasar
# Processing record 56 of Set 1 | yumen
# Processing record 57 of Set 1 | rohri
# Processing record 58 of Set 1 | mar del plata
# Processing record 59 of Set 1 | tuktoyaktuk
# Processing record 60 of Set 1 | ornskoldsvik
# Processing record 61 of Set 1 | kalemie
# Processing record 62 of Set 1 | daru
# Processing record 63 of Set 1 | deputatskiy
# Record not found
# Processing record 64 of Set 1 | vaini
# Processing record 65 of Set 1 | najran
# Processing record 66 of Set 1 | charters towers
# Record not found
# Processing record 67 of Set 1 | lodwar
# Processing record 68 of Set 1 | marawi
# Processing record 69 of Set 1 | erenhot
# Processing record 70 of Set 1 | saldanha
# Processing record 71 of Set 1 | caborca
# Processing record 72 of Set 1 | mataura
# Processing record 73 of Set 1 | hithadhoo
# Processing record 74 of Set 1 | kieta
# Processing record 75 of Set 1 | quchan
# Processing record 76 of Set 1 | puerto ayora
# Processing record 77 of Set 1 | labuhan
# Processing record 78 of Set 1 | constitucion
# Processing record 79 of Set 1 | campos novos
# Processing record 80 of Set 1 | niksar
# Processing record 81 of Set 1 | hermanus
# Processing record 82 of Set 1 | ponta delgada
# Processing record 83 of Set 1 | doha
# Record not found
# Record not found
# Processing record 84 of Set 1 | alice springs
# Processing record 85 of Set 1 | tuatapere
# Processing record 86 of Set 1 | iqaluit
# Processing record 87 of Set 1 | yellowknife
# Processing record 88 of Set 1 | whitehorse
# Processing record 89 of Set 1 | bluff
# Processing record 90 of Set 1 | tura
# Processing record 91 of Set 1 | bandarbeyla
# Processing record 92 of Set 1 | cabo san lucas
# Processing record 93 of Set 1 | sao filipe
# Processing record 94 of Set 1 | provideniya
# Processing record 95 of Set 1 | dharchula
# Processing record 96 of Set 1 | beitbridge
# Processing record 97 of Set 1 | fernandina beach
# Processing record 98 of Set 1 | longyearbyen
# Processing record 99 of Set 1 | mahebourg
# Record not found
# Processing record 100 of Set 1 | torit
# Processing record 101 of Set 1 | alyangula
# Processing record 102 of Set 1 | weiser
# Processing record 103 of Set 1 | uruzgan
# Processing record 104 of Set 1 | saint george
# Processing record 105 of Set 1 | sladkovicovo
# Processing record 106 of Set 1 | richards bay
# Processing record 107 of Set 1 | itoman
# Processing record 108 of Set 1 | mpongwe
# Processing record 109 of Set 1 | sheridan
# Processing record 110 of Set 1 | harper
# Processing record 111 of Set 1 | yulara
# Processing record 112 of Set 1 | aylmer
# Processing record 113 of Set 1 | upernavik
# Processing record 114 of Set 1 | hay river
# Processing record 115 of Set 1 | anadyr
# Processing record 116 of Set 1 | pathein
# Processing record 117 of Set 1 | atuona
# Processing record 118 of Set 1 | arkhangelsk
# Processing record 119 of Set 1 | helena
# Record not found
# Processing record 120 of Set 1 | qaanaaq
# Processing record 121 of Set 1 | khatanga
# Processing record 122 of Set 1 | beidao
# Processing record 123 of Set 1 | kaitangata
# Processing record 124 of Set 1 | lagos
# Processing record 125 of Set 1 | nikolskoye
# Processing record 126 of Set 1 | batemans bay
# Processing record 127 of Set 1 | manaure
# Processing record 128 of Set 1 | dicabisagan
# Processing record 129 of Set 1 | berezovyy
# Processing record 130 of Set 1 | nome
# Processing record 131 of Set 1 | eureka
# Processing record 132 of Set 1 | avarua
# Processing record 133 of Set 1 | pontianak
# Record not found
# Processing record 134 of Set 1 | dasoguz
# Record not found
# Record not found
# Processing record 135 of Set 1 | esperance
# Processing record 136 of Set 1 | uzventis
# Processing record 137 of Set 1 | davila
# Processing record 138 of Set 1 | nantucket
# Processing record 139 of Set 1 | assiniboia
# Processing record 140 of Set 1 | xuddur
# Processing record 141 of Set 1 | senno
# Processing record 142 of Set 1 | roma
# Record not found
# Processing record 143 of Set 1 | aksha
# Record not found
# Processing record 144 of Set 1 | tasiilaq
# Processing record 145 of Set 1 | umm kaddadah
# Processing record 146 of Set 1 | sur
# Record not found
# Processing record 147 of Set 1 | burnie
# Processing record 148 of Set 1 | tautira
# Processing record 149 of Set 1 | otane
# Processing record 150 of Set 1 | trzebinia
# Processing record 151 of Set 1 | talnakh
# Record not found
# Processing record 152 of Set 1 | tiznit
# Processing record 153 of Set 1 | port lincoln
# Processing record 154 of Set 1 | ardakan
# Processing record 155 of Set 1 | kaeo
# Processing record 156 of Set 1 | caravelas
# Processing record 157 of Set 1 | saskylakh
# Processing record 158 of Set 1 | kasempa
# Processing record 159 of Set 1 | san patricio
# Processing record 160 of Set 1 | gambela
# Processing record 161 of Set 1 | castro
# Processing record 162 of Set 1 | jadu
# Processing record 163 of Set 1 | waingapu
# Processing record 164 of Set 1 | samarai
# Processing record 165 of Set 1 | sorland
# Processing record 166 of Set 1 | saint-pierre
# Processing record 167 of Set 1 | egvekinot
# Processing record 168 of Set 1 | coquimbo
# Processing record 169 of Set 1 | pisco
# Processing record 170 of Set 1 | clyde river
# Processing record 171 of Set 1 | katobu
# Processing record 172 of Set 1 | port elizabeth
# Processing record 173 of Set 1 | bathsheba
# Processing record 174 of Set 1 | san vicente
# Processing record 175 of Set 1 | kodiak
# Record not found
# Processing record 176 of Set 1 | kasongo-lunda
# Record not found
# Processing record 177 of Set 1 | port alfred
# Processing record 178 of Set 1 | kutum
# Processing record 179 of Set 1 | cape town
# Processing record 180 of Set 1 | cayenne
# Processing record 181 of Set 1 | east london
# Processing record 182 of Set 1 | fairbanks
# Processing record 183 of Set 1 | souillac
# Processing record 184 of Set 1 | alanya
# Processing record 185 of Set 1 | port hardy
# Processing record 186 of Set 1 | sola
# Processing record 187 of Set 1 | te anau
# Processing record 188 of Set 1 | faya
# Processing record 189 of Set 1 | ahuimanu
# Processing record 190 of Set 1 | baruun-urt
# Processing record 191 of Set 1 | valerianovsk
# Processing record 192 of Set 1 | kozhanka
# Processing record 193 of Set 1 | praia da vitoria
# Record not found
# Processing record 194 of Set 1 | fortuna
# Processing record 195 of Set 1 | petropavlovsk-kamchatskiy
# Processing record 196 of Set 1 | hami
# Processing record 197 of Set 1 | rossville
# Processing record 198 of Set 1 | bima
# Processing record 199 of Set 1 | chardara
# Record not found
# Processing record 200 of Set 1 | bengkulu
# Processing record 201 of Set 1 | catalao
# Processing record 202 of Set 1 | ilulissat
# Processing record 203 of Set 1 | vostok
# Processing record 204 of Set 1 | alofi
# Processing record 205 of Set 1 | tchibanga
# Processing record 206 of Set 1 | nuuk
# Processing record 207 of Set 1 | bethel
# Processing record 208 of Set 1 | cockburn town
# Processing record 209 of Set 1 | faanui
# Processing record 210 of Set 1 | lerwick
# Processing record 211 of Set 1 | pozhva
# Processing record 212 of Set 1 | lagoa
# Processing record 213 of Set 1 | sungaipenuh
# Processing record 214 of Set 1 | adrar
# Processing record 215 of Set 1 | mogadishu
# Processing record 216 of Set 1 | sitka
# Processing record 217 of Set 1 | conceicao da barra
# Processing record 218 of Set 1 | katsina
# Processing record 219 of Set 1 | jutai
# Processing record 220 of Set 1 | radovitskiy
# Processing record 221 of Set 1 | bismarck
# Processing record 222 of Set 1 | abu dhabi
# Processing record 223 of Set 1 | chuy
# Processing record 224 of Set 1 | vestmanna
# Processing record 225 of Set 1 | glazov
# Record not found
# Processing record 226 of Set 1 | atar
# Processing record 227 of Set 1 | airai
# Processing record 228 of Set 1 | aracuai
# Processing record 229 of Set 1 | belyy gorodok
# Processing record 230 of Set 1 | xichang
# Processing record 231 of Set 1 | vanderhoof
# Processing record 232 of Set 1 | wallaceburg
# Processing record 233 of Set 1 | victoria
# Processing record 234 of Set 1 | xinmin
# Processing record 235 of Set 1 | bandar-e anzali
# Processing record 236 of Set 1 | sinnamary
# Processing record 237 of Set 1 | olafsvik
# Processing record 238 of Set 1 | carnarvon
# Processing record 239 of Set 1 | bubaque
# Processing record 240 of Set 1 | lompoc
# Processing record 241 of Set 1 | hamilton
# Processing record 242 of Set 1 | kavieng
# Processing record 243 of Set 1 | aksarka
# Processing record 244 of Set 1 | barrow
# Record not found
# Processing record 245 of Set 1 | zeya
# Processing record 246 of Set 1 | isangel
# Processing record 247 of Set 1 | popondetta
# Processing record 248 of Set 1 | znamenskoye
# Processing record 249 of Set 1 | cherskiy
# Processing record 250 of Set 1 | douglas
# Processing record 251 of Set 1 | zambezi
# Processing record 252 of Set 1 | isiro
# Processing record 253 of Set 1 | grand gaube
# Processing record 254 of Set 1 | nortelandia
# Processing record 255 of Set 1 | hofn
# Processing record 256 of Set 1 | baghdad
# Processing record 257 of Set 1 | guangyuan
# Processing record 258 of Set 1 | dillon
# Processing record 259 of Set 1 | sovetskoye
# Processing record 260 of Set 1 | mungaa
# Processing record 261 of Set 1 | outlook
# Processing record 262 of Set 1 | malabang
# Processing record 263 of Set 1 | sysert
# Processing record 264 of Set 1 | nanortalik
# Processing record 265 of Set 1 | los llanos de aridane
# Processing record 266 of Set 1 | kapoeta
# Record not found
# Processing record 267 of Set 1 | aklavik
# Processing record 268 of Set 1 | jalu
# Processing record 269 of Set 1 | torbay
# Processing record 270 of Set 1 | hualmay
# Processing record 271 of Set 1 | jandaia do sul
# Processing record 272 of Set 1 | carutapera
# Processing record 273 of Set 1 | merauke
# Processing record 274 of Set 1 | mananjary
# Processing record 275 of Set 1 | muhlhausen
# Processing record 276 of Set 1 | tashtagol
# Processing record 277 of Set 1 | ust-nera
# Processing record 278 of Set 1 | praia
# Processing record 279 of Set 1 | westport
# Processing record 280 of Set 1 | sibu
# Record not found
# Processing record 281 of Set 1 | porto novo
# Processing record 282 of Set 1 | urumqi
# Processing record 283 of Set 1 | dourados
# Record not found
# Processing record 284 of Set 1 | huarmey
# Processing record 285 of Set 1 | ossora
# Record not found
# Processing record 286 of Set 1 | karasburg
# Processing record 287 of Set 1 | nelson bay
# Processing record 288 of Set 1 | banda aceh
# Processing record 289 of Set 1 | kefamenanu
# Processing record 290 of Set 1 | svetlaya
# Processing record 291 of Set 1 | oktyabrskiy
# Processing record 292 of Set 1 | scarborough
# Processing record 293 of Set 1 | pangnirtung
# Processing record 294 of Set 1 | tapachula
# Processing record 295 of Set 1 | manthani
# Processing record 296 of Set 1 | dunedin
# Processing record 297 of Set 1 | bilibino
# Processing record 298 of Set 1 | marsa matruh
# Processing record 299 of Set 1 | riyadh
# Record not found
# Processing record 300 of Set 1 | chapais
# Processing record 301 of Set 1 | kavaratti
# Processing record 302 of Set 1 | ribeira grande
# Processing record 303 of Set 1 | havoysund
# Processing record 304 of Set 1 | flin flon
# Processing record 305 of Set 1 | methoni
# Processing record 306 of Set 1 | turbat
# Processing record 307 of Set 1 | sandakan
# Processing record 308 of Set 1 | birnin kebbi
# Processing record 309 of Set 1 | banjar
# Processing record 310 of Set 1 | soller
# Processing record 311 of Set 1 | grindavik
# Processing record 312 of Set 1 | guerrero negro
# Processing record 313 of Set 1 | narbonne
# Processing record 314 of Set 1 | kindu
# Processing record 315 of Set 1 | rurrenabaque
# Processing record 316 of Set 1 | bilma
# Processing record 317 of Set 1 | luderitz
# Processing record 318 of Set 1 | sabang
# Processing record 319 of Set 1 | texarkana
# Processing record 320 of Set 1 | shimoda
# Processing record 321 of Set 1 | dehloran
# Processing record 322 of Set 1 | ekhabi
# Processing record 323 of Set 1 | bijar
# Processing record 324 of Set 1 | yuxia
# Processing record 325 of Set 1 | tandur
# Processing record 326 of Set 1 | nador
# Record not found
# Record not found
# Processing record 327 of Set 1 | muros
# Record not found
# Processing record 328 of Set 1 | virginia beach
# Processing record 329 of Set 1 | vermilion
# Processing record 330 of Set 1 | ostrovnoy
# Processing record 331 of Set 1 | college
# Processing record 332 of Set 1 | kodinsk
# Processing record 333 of Set 1 | dikson
# Processing record 334 of Set 1 | aksay
# Processing record 335 of Set 1 | holme
# Processing record 336 of Set 1 | saint-augustin
# Processing record 337 of Set 1 | hrastnik
# Processing record 338 of Set 1 | bambanglipuro
# Processing record 339 of Set 1 | la seyne-sur-mer
# Processing record 340 of Set 1 | gilbues
# Processing record 341 of Set 1 | mae ramat
# Processing record 342 of Set 1 | cooma
# Processing record 343 of Set 1 | ojinaga
# Processing record 344 of Set 1 | pompeu
# Processing record 345 of Set 1 | champerico
# Processing record 346 of Set 1 | baturaja
# Record not found
# Processing record 347 of Set 1 | guanica
# Processing record 348 of Set 1 | eidfjord
# Processing record 349 of Set 1 | natal
# Processing record 350 of Set 1 | portland
# Processing record 351 of Set 1 | kawalu
# Processing record 352 of Set 1 | aden
# Processing record 353 of Set 1 | victoria point
# Processing record 354 of Set 1 | kalakamati
# Processing record 355 of Set 1 | sao joao da barra
# Processing record 356 of Set 1 | luebo
# Processing record 357 of Set 1 | balikpapan
# Processing record 358 of Set 1 | sumbe
# Processing record 359 of Set 1 | beringovskiy
# Processing record 360 of Set 1 | ponta do sol
# Processing record 361 of Set 1 | miri
# Processing record 362 of Set 1 | christchurch
# Processing record 363 of Set 1 | gueret
# Processing record 364 of Set 1 | strezhevoy
# Processing record 365 of Set 1 | macau
# Processing record 366 of Set 1 | brownsville
# Processing record 367 of Set 1 | lac-megantic
# Processing record 368 of Set 1 | asau
# Processing record 369 of Set 1 | khasan
# Processing record 370 of Set 1 | laela
# Record not found
# Processing record 371 of Set 1 | barreirinha
# Processing record 372 of Set 1 | birjand
# Processing record 373 of Set 1 | severo-kurilsk
# Processing record 374 of Set 1 | dhidhdhoo
# Record not found
# Processing record 375 of Set 1 | ust-ilimsk
# Processing record 376 of Set 1 | vila
# Processing record 377 of Set 1 | port blair
# Processing record 378 of Set 1 | codrington
# Processing record 379 of Set 1 | sechelt
# Processing record 380 of Set 1 | ilo
# Processing record 381 of Set 1 | namibe
# Processing record 382 of Set 1 | yar-sale
# Processing record 383 of Set 1 | isabela
# Processing record 384 of Set 1 | cap malheureux
# Processing record 385 of Set 1 | alta floresta
# Processing record 386 of Set 1 | mumbwa
# Processing record 387 of Set 1 | dalbandin
# Processing record 388 of Set 1 | big rapids
# Processing record 389 of Set 1 | camana
# Processing record 390 of Set 1 | sechura
# Processing record 391 of Set 1 | hue
# Processing record 392 of Set 1 | ulladulla
# Processing record 393 of Set 1 | ngorongoro
# Processing record 394 of Set 1 | terrace
# Processing record 395 of Set 1 | narsaq
# Processing record 396 of Set 1 | gidam
# Processing record 397 of Set 1 | hasaki
# Processing record 398 of Set 1 | kenai
# Processing record 399 of Set 1 | taloda
# Processing record 400 of Set 1 | kuala terengganu
# Processing record 401 of Set 1 | itapuranga
# Record not found
# Record not found
# Processing record 402 of Set 1 | barsovo
# Processing record 403 of Set 1 | balakhta
# Processing record 404 of Set 1 | weligama
# Processing record 405 of Set 1 | itaituba
# Processing record 406 of Set 1 | mora
# Processing record 407 of Set 1 | tevaitoa
# Processing record 408 of Set 1 | evensk
# Record not found
# Processing record 409 of Set 1 | paradise
# Processing record 410 of Set 1 | san rafael
# Processing record 411 of Set 1 | taoudenni
# Processing record 412 of Set 1 | terekli-mekteb
# Processing record 413 of Set 1 | cairns
# Processing record 414 of Set 1 | lavrentiya
# Record not found
# Processing record 415 of Set 1 | vila velha
# Processing record 416 of Set 1 | noumea
# Processing record 417 of Set 1 | bahia blanca
# Processing record 418 of Set 1 | baykit
# Processing record 419 of Set 1 | khash
# Processing record 420 of Set 1 | hambantota
# Processing record 421 of Set 1 | santo antonio do ica
# Processing record 422 of Set 1 | yefremov
# Processing record 423 of Set 1 | yerofey pavlovich
# Processing record 424 of Set 1 | conceicao das alagoas
# Processing record 425 of Set 1 | qujing
# Processing record 426 of Set 1 | tianpeng
# Processing record 427 of Set 1 | oranjestad
# Record not found
# Processing record 428 of Set 1 | mapiripan
# Processing record 429 of Set 1 | salalah
# Processing record 430 of Set 1 | gander
# Processing record 431 of Set 1 | alihe
# Processing record 432 of Set 1 | navrongo
# Processing record 433 of Set 1 | firozpur
# Processing record 434 of Set 1 | asyut
# Processing record 435 of Set 1 | mbandaka
# Processing record 436 of Set 1 | santa maria
# Processing record 437 of Set 1 | tiarei
# Processing record 438 of Set 1 | saint paul
# Record not found
# Processing record 439 of Set 1 | fairview
# Processing record 440 of Set 1 | brae
# Processing record 441 of Set 1 | medford
# Processing record 442 of Set 1 | ugoofaaru
# Processing record 443 of Set 1 | north bend
# Processing record 444 of Set 1 | maningrida
# Processing record 445 of Set 1 | sovetskiy
# Processing record 446 of Set 1 | jiblah
# Processing record 447 of Set 1 | berlevag
# Processing record 448 of Set 1 | goundam
# Processing record 449 of Set 1 | ayan
# Processing record 450 of Set 1 | tazovskiy
# Processing record 451 of Set 1 | chifeng
# Processing record 452 of Set 1 | ponferrada
# Processing record 453 of Set 1 | solwezi
# Processing record 454 of Set 1 | amot
# Processing record 455 of Set 1 | saryg-sep
# Processing record 456 of Set 1 | santiago
# Processing record 457 of Set 1 | saint anthony
# Processing record 458 of Set 1 | farkhor
# Processing record 459 of Set 1 | oranjemund
# Processing record 460 of Set 1 | seredeyskiy
# Processing record 461 of Set 1 | pemba
# Processing record 462 of Set 1 | vanimo
# Processing record 463 of Set 1 | leningradskiy
# Processing record 464 of Set 1 | pervomayskiy
# Processing record 465 of Set 1 | viedma
# Processing record 466 of Set 1 | cedar city
# Processing record 467 of Set 1 | mandalgovi
# Processing record 468 of Set 1 | arlit
# Processing record 469 of Set 1 | claresholm
# Processing record 470 of Set 1 | sulangan
# Processing record 471 of Set 1 | raybag
# Processing record 472 of Set 1 | tsiroanomandidy
# Processing record 473 of Set 1 | vestmannaeyjar
# Processing record 474 of Set 1 | mangrul pir
# Record not found
# Processing record 475 of Set 1 | lufilufi
# Processing record 476 of Set 1 | thunder bay
# Processing record 477 of Set 1 | wuwei
# Processing record 478 of Set 1 | yangliuqing
# Processing record 479 of Set 1 | tual
# Processing record 480 of Set 1 | zvishavane
# Processing record 481 of Set 1 | nassau
# Processing record 482 of Set 1 | turukhansk
# Processing record 483 of Set 1 | roebourne
# Processing record 484 of Set 1 | padang
# Processing record 485 of Set 1 | klyuchi
# Processing record 486 of Set 1 | half moon bay
# Processing record 487 of Set 1 | port macquarie
# Processing record 488 of Set 1 | mindelo
# Processing record 489 of Set 1 | vysokogornyy
# Processing record 490 of Set 1 | acajutla
# Processing record 491 of Set 1 | tokur
# Processing record 492 of Set 1 | madimba
# Processing record 493 of Set 1 | turinskaya sloboda
# Processing record 494 of Set 1 | tulum
# Processing record 495 of Set 1 | sept-iles
# Processing record 496 of Set 1 | pyapon
# Processing record 497 of Set 1 | satana
# Processing record 498 of Set 1 | umm lajj
# Processing record 499 of Set 1 | nagato
# Record not found
# Processing record 500 of Set 1 | san quintin
# Processing record 501 of Set 1 | beloha
# Processing record 502 of Set 1 | phenix city
# Processing record 503 of Set 1 | caraquet
# Processing record 504 of Set 1 | miramar
# Processing record 505 of Set 1 | gat
# Processing record 506 of Set 1 | micheweni
# Processing record 507 of Set 1 | hovd
# Processing record 508 of Set 1 | shama
# Processing record 509 of Set 1 | henties bay
# Processing record 510 of Set 1 | ladushkin
# Processing record 511 of Set 1 | beira
# Processing record 512 of Set 1 | udachnyy
# Processing record 513 of Set 1 | inongo
# Processing record 514 of Set 1 | oriximina
# Processing record 515 of Set 1 | patnanungan
# Processing record 516 of Set 1 | benito juarez
# Processing record 517 of Set 1 | nandyal
# Processing record 518 of Set 1 | altay
# Record not found
# Processing record 519 of Set 1 | udarnyy
# Processing record 520 of Set 1 | vila franca do campo
# Processing record 521 of Set 1 | dabakala
# Processing record 522 of Set 1 | lorengau
# Processing record 523 of Set 1 | svetlogorsk
# Processing record 524 of Set 1 | mets masrik
# Processing record 525 of Set 1 | mankono
# Processing record 526 of Set 1 | seoul
# Record not found
# Processing record 527 of Set 1 | sangar
# Processing record 528 of Set 1 | santa fe
# Processing record 529 of Set 1 | quatre cocos
# Processing record 530 of Set 1 | samfya
# Processing record 531 of Set 1 | novo aripuana
# Processing record 532 of Set 1 | cidreira
# Processing record 533 of Set 1 | caramay
# Record not found
# Processing record 534 of Set 1 | bagotville
# Processing record 535 of Set 1 | kintampo
# Processing record 536 of Set 1 | dingle
# Processing record 537 of Set 1 | aripuana
# Processing record 538 of Set 1 | leua
# Processing record 539 of Set 1 | dareda
# Processing record 540 of Set 1 | juegang
# Processing record 541 of Set 1 | price
# Processing record 542 of Set 1 | dolinsk
# Processing record 543 of Set 1 | sabzevar
# Processing record 544 of Set 1 | constantine
# Processing record 545 of Set 1 | kulu
# Processing record 546 of Set 1 | ipixuna
# Processing record 547 of Set 1 | margate
# Processing record 548 of Set 1 | chapada dos guimaraes
# Processing record 549 of Set 1 | komsomolskiy
# Processing record 550 of Set 1 | kenitra
# Processing record 551 of Set 1 | heishan
# Processing record 552 of Set 1 | chernyshevskiy
# Processing record 553 of Set 1 | ostrow mazowiecka
# Processing record 554 of Set 1 | tongren
# Processing record 555 of Set 1 | korla
# Processing record 556 of Set 1 | lianyuan
# Processing record 557 of Set 1 | vicuna
# Processing record 558 of Set 1 | lahad datu
# Processing record 559 of Set 1 | rio gallegos
# Record not found
# Processing record 560 of Set 1 | flinders
# Processing record 561 of Set 1 | iskateley
# Processing record 562 of Set 1 | tigil

# %%
# Convert array of JSONs into Pandas DataFrame

weather_dict = {"City": cityname,"Latitude": lat, "Longitude":lng,
                "Max Temp":max_temp,"Humidity":humidity,"Cloudiness":cloudiness,
                "Wind Speed":wind_speed,"Country":country, "Date":date}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#               City  Latitude  Longitude  Max Temp  Humidity  Cloudiness  \
# 0     Forest Grove   45.5198  -123.1107     65.17        67          26
# 1  Arraial do Cabo  -22.9661   -42.0278     70.02        77          83
# 2           Albany   42.6001   -73.9662     67.12        94          59
# 3           Broome   42.2506   -75.8330     62.58        94          13
# 4             Hilo   19.7297  -155.0900     76.17        65          87
#
#    Wind Speed Country        Date
# 0        5.95      US  1592546400
# 1       13.51      BR  1592546400
# 2        2.57      US  1592546400
# 3        3.29      US  1592546400
# 4        2.95      US  1592546400

# %%
# Export the City_Data into a csv
weather_data.to_csv(r'output_data\my_weather_data.csv')

# %%
# Scatter plot for latitude vs. temperature
scatlat = weather_data["Latitude"]
scattemp = weather_data["Max Temp"]

plt.scatter(scatlat,scattemp)
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('output_data/scatplotlatitudemaxtemp')
plt.show()
print("This scatter plot shows how temperature varies based on Latitude.")

# Scatter plot for latitude vs. humidity
scathumid = weather_data["Humidity"]

plt.scatter(scatlat,scathumid)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('output_data/scatplotlatitudehumidity')
plt.show()
print("This scatter plot shows how temperature correlates with humidity.")

# Scatter plot for latitude vs. cloudiness
scatcloud = weather_data["Cloudiness"]

plt.scatter(scatlat,scatcloud)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('output_data/scatplotlatitudecloudiness')
plt.show()
print("This scatter plot analyzes if any correlation exists between cloudiness and    city latitude.")

# Scatter plot for latitude vs. wind speed
scatwind = weather_data["Wind Speed"]

plt.scatter(scatlat,scatwind)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('output_data/scatplotlatitudewindspeed')
plt.show()
# Out:
# This scatter plot shows how temperature varies based on Latitude.
# This scatter plot shows how temperature correlates with humidity.
# This scatter plot analyzes if any correlation exists between cloudiness and    city latitude.

# %%
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=14,color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue}")
    plt.show()

# %%
northlat_df = weather_data.loc[weather_data["Latitude"] >= 0,:]
southlat_df = weather_data.loc[weather_data["Latitude"] < 0,:]

# %% [markdown]
# # Temperature (F) vs. Latitude

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Max Temp"]
plt.title("Northern Hemisphere - Temperature (F) vs Latitude")
plot_linear_regression(x_values,y_values,'Max Temp',(6,30))

plt.savefig('output_data/Northern Hemisphere - Temperature (F) vs Latitude')

x_values = southlat_df["Latitude"]
y_values = southlat_df["Max Temp"]
plt.title("Southern Hemisphere - Temperature (F) vs Latitude")
plot_linear_regression(x_values,y_values,'Max Temp',(6,30))

plt.savefig('output_data/Southern Hemisphere - Temperature (F) vs Latitude')
# Out:
# The r-squared is: -0.6643332516329329
# The r-squared is: 0.7301888685004974

# %% [markdown]
# # Humidity (%) vs. Latitude

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Humidity"]
plt.title("Northern Hemisphere - Humidity (%) vs Latitude")
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig("output_data/Northern Hemisphere - Humidity (%) vs Latitude")

x_values = southlat_df["Latitude"]
y_values = southlat_df["Humidity"]
plt.title("Southern Hemisphere - Humidity (%) vs Latitude")
plot_linear_regression(x_values,y_values,'Humidity',(6,30))

plt.savefig('output_data/Southern Hemisphere - Humidity (%) vs Latitude')
# Out:
# The r-squared is: -0.008940784071543603
# The r-squared is: 0.17854053232130515

# %% [markdown]
# # Cloudiness (%) vs. Latitude

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Cloudiness"]
plt.title("Northern Hemisphere - Cloudiness (%) vs Latitude")
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig("output_data/Northern Hemisphere - Cloudiness (%) vs Latitude")

x_values = southlat_df["Latitude"]
y_values = southlat_df["Cloudiness"]
plt.title("Southern Hemisphere - Cloudiness (%) vs Latitude")
plot_linear_regression(x_values,y_values,'Cloudiness',(6,30))

plt.savefig("output_data/Southern Hemisphere - Cloudiness (%) vs Latitude")
# Out:
# The r-squared is: 0.008329858133756274
# The r-squared is: 0.1120272941255397

# %% [markdown]
# # Wind Speed (mph) vs. Latitude

# %%
x_values = northlat_df["Latitude"]
y_values = northlat_df["Wind Speed"]
plt.title("Northern Hemisphere - Wind Speed (mph) vs Latitude")
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig("output_data/Northern Hemisphere - Wind Speed (mph) vs Latitude")

x_values = southlat_df["Latitude"]
y_values = southlat_df["Wind Speed"]
plt.title("Southern Hemisphere - Wind Speed (mph) vs Latitude")
plot_linear_regression(x_values,y_values,'Wind Speed',(6,30))

plt.savefig("output_data/Southern Hemisphere - Wind Speed (mph) vs Latitude")
# Out:
# The r-squared is: -0.00532775204988224
# The r-squared is: -0.07779612850354153
